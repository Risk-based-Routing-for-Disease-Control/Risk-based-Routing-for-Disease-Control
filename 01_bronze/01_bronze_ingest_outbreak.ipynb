# %% [markdown]
# #### HPAI 발생 이력 적재
# ##### Blob Storage raw CSV → Delta Bronze 적재
# ##### Blob 경로: raw/outbreak/kahis_hpai.json

# %%
import sys
sys.path.append("/Workspace/방역로/00_Shared_Utils")
from utils_config import CATALOG

BASE_PATH = "abfss://raw@dt4team1blob.dfs.core.windows.net/raw"

# HPAI 발생 이력 적재
df_outbreak = spark.read.option("multiLine", "true").json(f"{BASE_PATH}/outbreak/")
df_outbreak.write.format("delta").mode("overwrite").option("overwriteSchema", "true").saveAsTable(f"{CATALOG}.raw.outbreak")

print(df_outbreak.count())
